# %%
import numpy as np
import pandas as pd
import os
import glob
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
inp_files = glob.glob('/content/drive/MyDrive/ace_level2_98_11/centered_20min_input/*.csv')
tar_file = '/content/drive/MyDrive/ace_level2_98_11/SWICS_all.csv'

# %%
inp_df = pd.DataFrame()
for file in inp_files:
    temp = pd.read_csv(file, engine="python", encoding="UTF-8")
    inp_df = pd.concat([inp_df, temp])

# %%
tar_df = pd.read_csv(tar_file, engine="python", encoding="UTF-8")

# %%
tar_df
# Out:
#                       datetime    C6to5     O7to6     FetoO  \
# 0      1998-02-04 00:09:16.416  1.76360  0.367830       NaN
# 1      1998-02-04 02:10:26.976  1.44520  0.365160  0.151770
# 2      1998-02-04 04:11:38.400  0.93360  0.185370  0.538620
# 3      1998-02-04 06:12:49.824  0.87715  0.371970  0.481570
# 4      1998-02-04 08:14:01.248  1.50650  0.307440  0.575380
# ...                        ...      ...       ...       ...
# 59174  2011-08-21 13:40:48.000  0.47252  0.050033  0.092960
# 59175  2011-08-21 15:40:50.304  0.57866  0.033956  0.140230
# 59176  2011-08-21 17:40:50.880  0.57597  0.029067  0.081298
# 59177  2011-08-21 19:40:53.184  1.02060  0.070335  0.115320
# 59178  2011-08-21 21:40:53.760  0.72299  0.076068  0.165440
#
#                datetime_re      Vp_avg label1 label2  is_CME
# 0      1998-02-04 00:00:00         NaN    NaN    NaN       0
# 1      1998-02-04 02:20:00         NaN    NaN    NaN       0
# 2      1998-02-04 04:20:00         NaN    NaN    NaN       1
# 3      1998-02-04 06:20:00         NaN    NaN    NaN       1
# 4      1998-02-04 08:20:00         NaN    NaN    NaN       1
# ...                    ...         ...    ...    ...     ...
# 59174  2011-08-21 13:40:00  412.823697   slow   slow       0
# 59175  2011-08-21 15:40:00  404.887535   slow   slow       0
# 59176  2011-08-21 17:40:00  403.272516   slow   slow       0
# 59177  2011-08-21 19:40:00  400.375427   slow   slow       0
# 59178  2011-08-21 21:40:00  399.455965   slow   slow       0
#
# [59179 rows x 9 columns]

# %%
inp_df
# Out:
#                datetime          Vp  Alpha_ratio  entropy  Alfvenicity label1  \
# 0       1998-02-04 0:00         NaN          NaN      NaN          NaN    NaN
# 1       1998-02-04 0:20         NaN          NaN      NaN          NaN    NaN
# 2       1998-02-04 0:40         NaN          NaN      NaN          NaN    NaN
# 3       1998-02-04 1:00         NaN          NaN      NaN          NaN    NaN
# 4       1998-02-04 1:20         NaN          NaN      NaN          NaN    NaN
# ...                 ...         ...          ...      ...          ...    ...
# 16772  2011-08-21 22:40  402.700667          NaN      NaN          NaN   slow
# 16773  2011-08-21 23:00  397.862000          NaN      NaN          NaN   slow
# 16774  2011-08-21 23:20  423.855294          NaN      NaN          NaN   slow
# 16775  2011-08-21 23:40  403.462778          NaN      NaN          NaN   slow
# 16776   2011-08-22 0:00  389.741429          NaN      NaN          NaN   slow
#
#       label2  Np           Tp  coulomb num  sigma_r
# 0        NaN NaN          NaN          NaN      NaN
# 1        NaN NaN          NaN          NaN      NaN
# 2        NaN NaN          NaN          NaN      NaN
# 3        NaN NaN          NaN          NaN      NaN
# 4        NaN NaN          NaN          NaN      NaN
# ...      ...  ..          ...          ...      ...
# 16772    NaN NaN  90045.46667          NaN      NaN
# 16773    NaN NaN  97787.30769          NaN      NaN
# 16774    NaN NaN  63540.81250          NaN      NaN
# 16775    NaN NaN  57720.86667          NaN      NaN
# 16776    NaN NaN          NaN          NaN      NaN
#
# [356185 rows x 11 columns]

# %%
inp_df['datetime'] = pd.to_datetime(inp_df['datetime'])
tar_df['datetime_re'] = pd.to_datetime(tar_df['datetime_re'])

# %%
inp_time = inp_df['datetime']
tar_time = tar_df['datetime_re'][1:]

# %%
time_to_idx = {t: i for i, t in enumerate(inp_time)}
idxs = np.array([time_to_idx[t] for t in tar_time], dtype=int)

inp_data_col = ['Vp', 'Alpha_ratio', 'entropy', 'Alfvenicity', 'Np', 'Tp', 'coulomb num']
inp_df['Alfvenicity'] = inp_df['Alfvenicity'].abs() # abs(Alfvenicity)
tar_data_col = ['C6to5', 'O7to6', 'FetoO', 'is_CME']

inp_array = inp_df[inp_data_col].values
tar_array = tar_df[tar_data_col].values[1:]
is_cme_array = tar_df['is_CME'].values[1:]

inp_windows = np.full((len(idxs), 7, len(inp_data_col)), np.nan, dtype=float)

for i, idx in enumerate(idxs):
    inp_windows[i] = inp_array[idx-3:idx+4]

# %%
inp_windows.shape
# Out:
# (59178, 7, 7)

# %%
tar_array.shape
# Out:
# (59178, 4)

# %%
len(tar_time)
# Out:
# 59178

# %%
tar_missing = set(np.where(np.isnan(tar_array))[0])
inp_missing = set(np.where(np.isnan(inp_windows).sum(axis=1) >= 5.)[0])

# %%
missing_idx = tar_missing | inp_missing
valid_idx = sorted(list(set(range(len(tar_array))) - missing_idx))

# %%
len(valid_idx)
# Out:
# 39436

# %%
inp = inp_windows[valid_idx]
tar = tar_array[valid_idx]
time = tar_time.values[valid_idx]
is_cme = is_cme_array[valid_idx]

# %%
print("입력 데이터(inp) shape:", inp.shape)
print("타겟 데이터(tar) shape:", tar.shape)
print("시간 데이터(time) shape:", time.shape)
print("CME (is_cme) shape:", is_cme.shape)
# Out:
# 입력 데이터(inp) shape: (39436, 7, 7)
# 타겟 데이터(tar) shape: (39436, 4)
# 시간 데이터(time) shape: (39436,)
# CME (is_cme) shape: (39436,)

# %%
np.savez_compressed(
    'full_dataset.npz',
    inp=inp,
    tar=tar[:, :-1],
    time=time,
    is_cme=tar[:, -1] # is_cme를 분리해서 저장합니다.
)

# %%
loaded_dataset = np.load('full_dataset.npz', allow_pickle=True)

print(list(loaded_dataset.keys()))
print(loaded_dataset['inp'].shape)
print(loaded_dataset['tar'].shape)
print(loaded_dataset['is_cme'].shape)
# Out:
# ['inp', 'tar', 'time', 'is_cme']
# (39436, 7, 7)
# (39436, 3)
# (39436,)
